# %%
import pandas as pd
df_2016 = pd.read_csv('/Users/xorse/Documents/Data Sc Learning/energy-analyst-data-exercise-public-master/historicalPriceData/ERCOT_DA_Prices_2016.csv')
df_2017 = pd.read_csv('/Users/xorse/Documents/Data Sc Learning/energy-analyst-data-exercise-public-master/historicalPriceData/ERCOT_DA_Prices_2017.csv')
df_2018 = pd.read_csv('/Users/xorse/Documents/Data Sc Learning/energy-analyst-data-exercise-public-master/historicalPriceData/ERCOT_DA_Prices_2018.csv')

# %%
df_2017.head()
# Out:
#                   Date SettlementPoint  Price
# 0  2017-01-01 00:00:00       HB_BUSAVG  23.23
# 1  2017-01-01 00:00:00      HB_HOUSTON  23.23
# 2  2017-01-01 00:00:00       HB_HUBAVG  23.23
# 3  2017-01-01 00:00:00        HB_NORTH  23.23
# 4  2017-01-01 00:00:00        HB_SOUTH  23.23

# %%
df = pd.concat([df_2016, df_2017, df_2018])

# %%
df
# Out:
#                        Date SettlementPoint  Price
# 0       2016-01-01 00:00:00       HB_BUSAVG  18.42
# 1       2016-01-01 00:00:00      HB_HOUSTON  18.42
# 2       2016-01-01 00:00:00       HB_HUBAVG  18.42
# 3       2016-01-01 00:00:00        HB_NORTH  18.43
# 4       2016-01-01 00:00:00        HB_SOUTH  18.38
# ...                     ...             ...    ...
# 122621  2018-12-31 23:00:00         LZ_LCRA  20.54
# 122622  2018-12-31 23:00:00        LZ_NORTH  20.49
# 122623  2018-12-31 23:00:00        LZ_RAYBN  20.49
# 122624  2018-12-31 23:00:00        LZ_SOUTH  21.68
# 122625  2018-12-31 23:00:00         LZ_WEST  25.52
#
# [368214 rows x 3 columns]

# %%
df[['year', 'month', 'day_time']] = df['Date'].str.split('-', expand = True)
df
# Out:
#                        Date SettlementPoint  Price  year month     day_time
# 0       2016-01-01 00:00:00       HB_BUSAVG  18.42  2016    01  01 00:00:00
# 1       2016-01-01 00:00:00      HB_HOUSTON  18.42  2016    01  01 00:00:00
# 2       2016-01-01 00:00:00       HB_HUBAVG  18.42  2016    01  01 00:00:00
# 3       2016-01-01 00:00:00        HB_NORTH  18.43  2016    01  01 00:00:00
# 4       2016-01-01 00:00:00        HB_SOUTH  18.38  2016    01  01 00:00:00
# ...                     ...             ...    ...   ...   ...          ...
# 122621  2018-12-31 23:00:00         LZ_LCRA  20.54  2018    12  31 23:00:00
# 122622  2018-12-31 23:00:00        LZ_NORTH  20.49  2018    12  31 23:00:00
# 122623  2018-12-31 23:00:00        LZ_RAYBN  20.49  2018    12  31 23:00:00
# 122624  2018-12-31 23:00:00        LZ_SOUTH  21.68  2018    12  31 23:00:00
# 122625  2018-12-31 23:00:00         LZ_WEST  25.52  2018    12  31 23:00:00
#
# [368214 rows x 6 columns]

# %%
del df['day_time']

# %%
df[['year', 'month', 'day_time']] = df['Date'].str.split('-', expand = True)
df
# Out:
#                        Date SettlementPoint  Price  year month     day_time
# 0       2016-01-01 00:00:00       HB_BUSAVG  18.42  2016    01  01 00:00:00
# 1       2016-01-01 00:00:00      HB_HOUSTON  18.42  2016    01  01 00:00:00
# 2       2016-01-01 00:00:00       HB_HUBAVG  18.42  2016    01  01 00:00:00
# 3       2016-01-01 00:00:00        HB_NORTH  18.43  2016    01  01 00:00:00
# 4       2016-01-01 00:00:00        HB_SOUTH  18.38  2016    01  01 00:00:00
# ...                     ...             ...    ...   ...   ...          ...
# 122621  2018-12-31 23:00:00         LZ_LCRA  20.54  2018    12  31 23:00:00
# 122622  2018-12-31 23:00:00        LZ_NORTH  20.49  2018    12  31 23:00:00
# 122623  2018-12-31 23:00:00        LZ_RAYBN  20.49  2018    12  31 23:00:00
# 122624  2018-12-31 23:00:00        LZ_SOUTH  21.68  2018    12  31 23:00:00
# 122625  2018-12-31 23:00:00         LZ_WEST  25.52  2018    12  31 23:00:00
#
# [368214 rows x 6 columns]

# %%
df
# Out:
#                        Date SettlementPoint  Price  year month     day_time
# 0       2016-01-01 00:00:00       HB_BUSAVG  18.42  2016    01  01 00:00:00
# 1       2016-01-01 00:00:00      HB_HOUSTON  18.42  2016    01  01 00:00:00
# 2       2016-01-01 00:00:00       HB_HUBAVG  18.42  2016    01  01 00:00:00
# 3       2016-01-01 00:00:00        HB_NORTH  18.43  2016    01  01 00:00:00
# 4       2016-01-01 00:00:00        HB_SOUTH  18.38  2016    01  01 00:00:00
# ...                     ...             ...    ...   ...   ...          ...
# 122621  2018-12-31 23:00:00         LZ_LCRA  20.54  2018    12  31 23:00:00
# 122622  2018-12-31 23:00:00        LZ_NORTH  20.49  2018    12  31 23:00:00
# 122623  2018-12-31 23:00:00        LZ_RAYBN  20.49  2018    12  31 23:00:00
# 122624  2018-12-31 23:00:00        LZ_SOUTH  21.68  2018    12  31 23:00:00
# 122625  2018-12-31 23:00:00         LZ_WEST  25.52  2018    12  31 23:00:00
#
# [368214 rows x 6 columns]

# %%
del df['Date']

# %%
pivot_df = pd.pivot_table(df, index = ['year', 'month', 'SettlementPoint'])
pivot_df.reset_index(inplace = True)
pivot_df
# Out:
#      year month SettlementPoint      Price
# 0    2016    01       HB_BUSAVG  19.209301
# 1    2016    01      HB_HOUSTON  19.565726
# 2    2016    01       HB_HUBAVG  19.258696
# 3    2016    01        HB_NORTH  19.133306
# 4    2016    01        HB_SOUTH  19.210054
# ..    ...   ...             ...        ...
# 499  2018    12         LZ_LCRA  30.582661
# 500  2018    12        LZ_NORTH  31.131949
# 501  2018    12        LZ_RAYBN  31.553535
# 502  2018    12        LZ_SOUTH  32.112728
# 503  2018    12         LZ_WEST  34.980847
#
# [504 rows x 4 columns]

# %%
df.head()
# Out:
#   SettlementPoint  Price  year month     day_time
# 0       HB_BUSAVG  18.42  2016    01  01 00:00:00
# 1      HB_HOUSTON  18.42  2016    01  01 00:00:00
# 2       HB_HUBAVG  18.42  2016    01  01 00:00:00
# 3        HB_NORTH  18.43  2016    01  01 00:00:00
# 4        HB_SOUTH  18.38  2016    01  01 00:00:00

# %%
df[['sett_type', 'sett_name']] = df['SettlementPoint'].str.split('_', expand = True)

# %%
df
# Out:
#        SettlementPoint  Price  year month     day_time sett_type sett_name
# 0            HB_BUSAVG  18.42  2016    01  01 00:00:00        HB    BUSAVG
# 1           HB_HOUSTON  18.42  2016    01  01 00:00:00        HB   HOUSTON
# 2            HB_HUBAVG  18.42  2016    01  01 00:00:00        HB    HUBAVG
# 3             HB_NORTH  18.43  2016    01  01 00:00:00        HB     NORTH
# 4             HB_SOUTH  18.38  2016    01  01 00:00:00        HB     SOUTH
# ...                ...    ...   ...   ...          ...       ...       ...
# 122621         LZ_LCRA  20.54  2018    12  31 23:00:00        LZ      LCRA
# 122622        LZ_NORTH  20.49  2018    12  31 23:00:00        LZ     NORTH
# 122623        LZ_RAYBN  20.49  2018    12  31 23:00:00        LZ     RAYBN
# 122624        LZ_SOUTH  21.68  2018    12  31 23:00:00        LZ     SOUTH
# 122625         LZ_WEST  25.52  2018    12  31 23:00:00        LZ      WEST
#
# [368214 rows x 7 columns]

# %%
HB_df = df[df['sett_type'] == 'HB']

# %%
HB_df_pos = HB_df[HB_df['Price'] > 0]

# %%
HB_df_pos['log_prices'] = np.log(HB_df_pos['Price'])

#adding a column to compute the ln of prices
# Out:
# /var/folders/n3/c8j37s9n0f5ftnp6gjw4tlw00000gn/T/ipykernel_54002/3011247605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HB_df_pos['log_prices'] = np.log(HB_df_pos['Price'])

# %%
HB_df_pos
# Out:
#        SettlementPoint  Price  year month     day_time sett_type sett_name  \
# 0            HB_BUSAVG  18.42  2016    01  01 00:00:00        HB    BUSAVG
# 1           HB_HOUSTON  18.42  2016    01  01 00:00:00        HB   HOUSTON
# 2            HB_HUBAVG  18.42  2016    01  01 00:00:00        HB    HUBAVG
# 3             HB_NORTH  18.43  2016    01  01 00:00:00        HB     NORTH
# 4             HB_SOUTH  18.38  2016    01  01 00:00:00        HB     SOUTH
# ...                ...    ...   ...   ...          ...       ...       ...
# 122613      HB_HOUSTON  20.00  2018    12  31 23:00:00        HB   HOUSTON
# 122614       HB_HUBAVG  20.53  2018    12  31 23:00:00        HB    HUBAVG
# 122615        HB_NORTH  20.47  2018    12  31 23:00:00        HB     NORTH
# 122616        HB_SOUTH  20.67  2018    12  31 23:00:00        HB     SOUTH
# 122617         HB_WEST  20.97  2018    12  31 23:00:00        HB      WEST
#
#         log_prices
# 0         2.913437
# 1         2.913437
# ...

# %%
import numpy as np

# %%
HB_log_pivot = pd.pivot_table(HB_df_pos, index = ['year', 'SettlementPoint'], values = ['log_prices'], aggfunc = [np.std])

# %%
HB_log_pivot.reset_index(inplace = True)

# %%
HB_log_pivot
# Out:
#     year SettlementPoint        std
#                          log_prices
# 0   2016       HB_BUSAVG   0.475685
# 1   2016      HB_HOUSTON   0.501116
# 2   2016       HB_HUBAVG   0.486760
# 3   2016        HB_NORTH   0.460743
# 4   2016        HB_SOUTH   0.516986
# 5   2016         HB_WEST   0.529661
# 6   2017       HB_BUSAVG   0.356690
# 7   2017      HB_HOUSTON   0.412538
# 8   2017       HB_HUBAVG   0.375370
# 9   2017        HB_NORTH   0.338474
# 10  2017        HB_SOUTH   0.365397
# 11  2017         HB_WEST   0.528184
# 12  2018       HB_BUSAVG   0.484018
# 13  2018      HB_HOUSTON   0.473559
# 14  2018       HB_HUBAVG   0.494216
# 15  2018        HB_NORTH   0.481392
# 16  2018        HB_SOUTH   0.471401
# 17  2018         HB_WEST   0.708518

# %%
HB_log_pivot.columns = ['Year', 'SettlementPoint', 'HourlyVolatility']

# %%
HB_log_pivot
# Out:
#     Year SettlementPoint  HourlyVolatility
# 0   2016       HB_BUSAVG          0.475685
# 1   2016      HB_HOUSTON          0.501116
# 2   2016       HB_HUBAVG          0.486760
# 3   2016        HB_NORTH          0.460743
# 4   2016        HB_SOUTH          0.516986
# 5   2016         HB_WEST          0.529661
# 6   2017       HB_BUSAVG          0.356690
# 7   2017      HB_HOUSTON          0.412538
# 8   2017       HB_HUBAVG          0.375370
# 9   2017        HB_NORTH          0.338474
# 10  2017        HB_SOUTH          0.365397
# 11  2017         HB_WEST          0.528184
# 12  2018       HB_BUSAVG          0.484018
# 13  2018      HB_HOUSTON          0.473559
# 14  2018       HB_HUBAVG          0.494216
# 15  2018        HB_NORTH          0.481392
# 16  2018        HB_SOUTH          0.471401
# 17  2018         HB_WEST          0.708518

# %%
HB_log_pivot.to_csv('HourlyVolatilityByYear.csv', index = False)

# %%
HB_2016 = HB_log_pivot[HB_log_pivot['Year'] == '2016'] #unneccesary.. ignore

# %%
HB_2017 = HB_log_pivot[HB_log_pivot['Year'] == '2017'] #unneccesary.. ignore

# %%
HB_2018 = HB_log_pivot[HB_log_pivot['Year'] == '2018'] #unneccesary.. ignore

# %%
HB_log_max = pd.pivot_table(HB_log_pivot, index = ['Year', 'SettlementPoint'], values = ['HourlyVolatility'], aggfunc = [np.max])

# %%
HB_log_max
# Out:
#                                  amax
#                      HourlyVolatility
# Year SettlementPoint
# 2016 HB_BUSAVG               0.475685
#      HB_HOUSTON              0.501116
#      HB_HUBAVG               0.486760
#      HB_NORTH                0.460743
#      HB_SOUTH                0.516986
#      HB_WEST                 0.529661
# 2017 HB_BUSAVG               0.356690
#      HB_HOUSTON              0.412538
#      HB_HUBAVG               0.375370
#      HB_NORTH                0.338474
#      HB_SOUTH                0.365397
#      HB_WEST                 0.528184
# 2018 HB_BUSAVG               0.484018
#      HB_HOUSTON              0.473559
#      HB_HUBAVG               0.494216
#      HB_NORTH                0.481392
#      HB_SOUTH                0.471401
#      HB_WEST                 0.708518

# %%
year_group = HB_log_pivot.groupby('Year')
maximum_year = year_group.max()
maximum_year.columns = ['SettlementPoint', 'HourlyVolatility']
maximum_year.reset_index()
# Out:
#    Year SettlementPoint  HourlyVolatility
# 0  2016         HB_WEST          0.529661
# 1  2017         HB_WEST          0.528184
# 2  2018         HB_WEST          0.708518

# %%
maximum_year.to_csv('MaxVolatilityByYear.csv', index = False)

# %%
df
# Out:
#                        Date SettlementPoint  Price
# 0       2016-01-01 00:00:00       HB_BUSAVG  18.42
# 1       2016-01-01 00:00:00      HB_HOUSTON  18.42
# 2       2016-01-01 00:00:00       HB_HUBAVG  18.42
# 3       2016-01-01 00:00:00        HB_NORTH  18.43
# 4       2016-01-01 00:00:00        HB_SOUTH  18.38
# ...                     ...             ...    ...
# 122621  2018-12-31 23:00:00         LZ_LCRA  20.54
# 122622  2018-12-31 23:00:00        LZ_NORTH  20.49
# 122623  2018-12-31 23:00:00        LZ_RAYBN  20.49
# 122624  2018-12-31 23:00:00        LZ_SOUTH  21.68
# 122625  2018-12-31 23:00:00         LZ_WEST  25.52
#
# [368214 rows x 3 columns]

# %%
df[['date', 'time']] = df['Date'].str.split(' ', expand = True)
df
# Out:
#                        Date SettlementPoint  Price        date      time
# 0       2016-01-01 00:00:00       HB_BUSAVG  18.42  2016-01-01  00:00:00
# 1       2016-01-01 00:00:00      HB_HOUSTON  18.42  2016-01-01  00:00:00
# 2       2016-01-01 00:00:00       HB_HUBAVG  18.42  2016-01-01  00:00:00
# 3       2016-01-01 00:00:00        HB_NORTH  18.43  2016-01-01  00:00:00
# 4       2016-01-01 00:00:00        HB_SOUTH  18.38  2016-01-01  00:00:00
# ...                     ...             ...    ...         ...       ...
# 122621  2018-12-31 23:00:00         LZ_LCRA  20.54  2018-12-31  23:00:00
# 122622  2018-12-31 23:00:00        LZ_NORTH  20.49  2018-12-31  23:00:00
# 122623  2018-12-31 23:00:00        LZ_RAYBN  20.49  2018-12-31  23:00:00
# 122624  2018-12-31 23:00:00        LZ_SOUTH  21.68  2018-12-31  23:00:00
# 122625  2018-12-31 23:00:00         LZ_WEST  25.52  2018-12-31  23:00:00
#
# [368214 rows x 5 columns]

# %%
df.groupby(['SettlementPoint']).groups.keys()
# Out:
# dict_keys(['HB_BUSAVG', 'HB_HOUSTON', 'HB_HUBAVG', 'HB_NORTH', 'HB_SOUTH', 'HB_WEST', 'LZ_AEN', 'LZ_CPS', 'LZ_HOUSTON', 'LZ_LCRA', 'LZ_NORTH', 'LZ_RAYBN', 'LZ_SOUTH', 'LZ_WEST'])

# %%
df.groupby(['SettlementPoint'])

# %%
df.head()
# Out:
#                   Date SettlementPoint  Price        date      time
# 0  2016-01-01 00:00:00       HB_BUSAVG  18.42  2016-01-01  00:00:00
# 1  2016-01-01 00:00:00      HB_HOUSTON  18.42  2016-01-01  00:00:00
# 2  2016-01-01 00:00:00       HB_HUBAVG  18.42  2016-01-01  00:00:00
# 3  2016-01-01 00:00:00        HB_NORTH  18.43  2016-01-01  00:00:00
# 4  2016-01-01 00:00:00        HB_SOUTH  18.38  2016-01-01  00:00:00

# %%
df_HB_BUSAVG = df[df['SettlementPoint'] == 'HB_BUSAVG']
df_HB_BUSAVG
# Out:
#                        Date SettlementPoint  Price        date      time
# 0       2016-01-01 00:00:00       HB_BUSAVG  18.42  2016-01-01  00:00:00
# 14      2016-01-01 01:00:00       HB_BUSAVG  16.15  2016-01-01  01:00:00
# 28      2016-01-01 02:00:00       HB_BUSAVG  15.61  2016-01-01  02:00:00
# 42      2016-01-01 03:00:00       HB_BUSAVG  15.62  2016-01-01  03:00:00
# 56      2016-01-01 04:00:00       HB_BUSAVG  15.94  2016-01-01  04:00:00
# ...                     ...             ...    ...         ...       ...
# 122556  2018-12-31 19:00:00       HB_BUSAVG  28.50  2018-12-31  19:00:00
# 122570  2018-12-31 20:00:00       HB_BUSAVG  26.21  2018-12-31  20:00:00
# 122584  2018-12-31 21:00:00       HB_BUSAVG  23.62  2018-12-31  21:00:00
# 122598  2018-12-31 22:00:00       HB_BUSAVG  22.60  2018-12-31  22:00:00
# 122612  2018-12-31 23:00:00       HB_BUSAVG  20.51  2018-12-31  23:00:00
#
# [26301 rows x 5 columns]

# %%
HB_BUSAVG_spot = df_HB_BUSAVG.pivot(index = 'date', columns = 'time', values = 'Price')
HB_BUSAVG_spot = HB_BUSAVG_spot.reset_index()

# %%
HB_BUSAVG_spot.rename(columns = {'time': 'Variable'}, inplace = True) 
HB_BUSAVG_spot
# Out:
# time     variable        date  00:00:00  01:00:00  02:00:00  03:00:00  \
# 0     ISONE_Node1  2016-01-01     18.42     16.15     15.61     15.62
# 1     ISONE_Node1  2016-01-02     18.99     17.94     17.16     17.00
# 2     ISONE_Node1  2016-01-03     17.44     16.46     16.18     16.35
# 3     ISONE_Node1  2016-01-04     17.01     17.07     17.47     18.00
# 4     ISONE_Node1  2016-01-05     15.89     15.88     15.99     16.50
# ...           ...         ...       ...       ...       ...       ...
# 1091  ISONE_Node1  2018-12-27     12.17      9.39      6.64      6.99
# 1092  ISONE_Node1  2018-12-28     20.11     19.36     18.91     18.85
# 1093  ISONE_Node1  2018-12-29     20.92     20.95     21.18     21.24
# 1094  ISONE_Node1  2018-12-30     24.92     23.90     24.51     23.31
# 1095  ISONE_Node1  2018-12-31     20.42     19.17     18.01     17.17
#
# time  04:00:00  05:00:00  06:00:00  07:00:00  ...  14:00:00  15:00:00  \
# ...

# %%
HB_BUSAVG_spot['Variable'] = 'ISONE_Node1'

# %%
HB_BUSAVG_spot.insert(0, 'variable', 'ISONE_Node1')

# %%
del HB_BUSAVG_spot['Variable']

# %%
HB_BUSAVG_spot.to_csv('spot_HB_BUSAVG.csv', index = False)

# %%
df.head()
# Out:
#                   Date SettlementPoint  Price        date      time
# 0  2016-01-01 00:00:00       HB_BUSAVG  18.42  2016-01-01  00:00:00
# 1  2016-01-01 00:00:00      HB_HOUSTON  18.42  2016-01-01  00:00:00
# 2  2016-01-01 00:00:00       HB_HUBAVG  18.42  2016-01-01  00:00:00
# 3  2016-01-01 00:00:00        HB_NORTH  18.43  2016-01-01  00:00:00
# 4  2016-01-01 00:00:00        HB_SOUTH  18.38  2016-01-01  00:00:00

# %%
df_HB_HOUSTON = df[df['SettlementPoint'] == 'HB_HOUSTON']
df_HB_HOUSTON
# Out:
#                        Date SettlementPoint  Price        date      time
# 1       2016-01-01 00:00:00      HB_HOUSTON  18.42  2016-01-01  00:00:00
# 15      2016-01-01 01:00:00      HB_HOUSTON  16.15  2016-01-01  01:00:00
# 29      2016-01-01 02:00:00      HB_HOUSTON  15.61  2016-01-01  02:00:00
# 43      2016-01-01 03:00:00      HB_HOUSTON  15.62  2016-01-01  03:00:00
# 57      2016-01-01 04:00:00      HB_HOUSTON  15.94  2016-01-01  04:00:00
# ...                     ...             ...    ...         ...       ...
# 122557  2018-12-31 19:00:00      HB_HOUSTON  27.31  2018-12-31  19:00:00
# 122571  2018-12-31 20:00:00      HB_HOUSTON  24.94  2018-12-31  20:00:00
# 122585  2018-12-31 21:00:00      HB_HOUSTON  22.50  2018-12-31  21:00:00
# 122599  2018-12-31 22:00:00      HB_HOUSTON  22.03  2018-12-31  22:00:00
# 122613  2018-12-31 23:00:00      HB_HOUSTON  20.00  2018-12-31  23:00:00
#
# [26301 rows x 5 columns]

# %%
HB_HOUSTON_spot = df_HB_HOUSTON.pivot(index = 'date', columns = 'time', values = 'Price')
HB_HOUSTON_spot = HB_HOUSTON_spot.reset_index()

# %%
HB_HOUSTON_spot
# Out:
# time        date  00:00:00  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  \
# 0     2016-01-01     18.42     16.15     15.61     15.62     15.94     16.69
# 1     2016-01-02     18.99     17.94     17.16     17.00     17.90     17.65
# 2     2016-01-03     17.44     16.45     16.18     16.35     17.01     17.69
# 3     2016-01-04     17.01     17.07     17.47     18.00     19.34     21.80
# 4     2016-01-05     15.89     15.88     15.99     16.50     18.00     21.19
# ...          ...       ...       ...       ...       ...       ...       ...
# 1091  2018-12-27     12.37      9.65      6.85      7.16      9.99     13.67
# 1092  2018-12-28     19.71     19.32     18.73     18.75     20.18     21.65
# 1093  2018-12-29     20.71     20.84     21.05     21.09     21.70     24.25
# 1094  2018-12-30     23.71     23.05     23.70     22.40     21.65     22.07
# 1095  2018-12-31     19.76     18.60     17.42     16.71     16.82     17.84
#
# ...

# %%
HB_HOUSTON_spot.insert(0, 'variable', 'ISONE_Node1')

# %%
HB_HOUSTON_spot.to_csv('spot_HB_HOUSTON.csv', index = False)
